# %%
# !pip install pygwalker
# Out:
# ...
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    ----------- ---------------------------- 1.3/4.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------- -------------- 2.9/4.5 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------- -- 4.2/4.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 6.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/956.2 kB ? eta -:--:--
#    ---------------------------------------- 956.2/956.2 kB 5.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.0 MB 6.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.0 MB 7.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/11.0 MB 7.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.0/11.0 MB 7.1 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pygwalker as pyg

# %%
filename_white = "https://raw.githubusercontent.com/clizarraga-UAD7/Datasets/main/wines/winequality-white.csv"
filename_red = "https://raw.githubusercontent.com/clizarraga-UAD7/Datasets/main/wines/winequality-red.csv"
